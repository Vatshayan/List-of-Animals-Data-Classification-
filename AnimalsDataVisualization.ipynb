# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
animals=pd.read_csv("Animals.csv")

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 7 columns):
# Animal                    255 non-null object
# Young                     301 non-null object
# Female                    227 non-null object
# Male                      235 non-null object
# Collective noun           447 non-null object
# Collateral adjective      256 non-null object
# Culinary noun for meat    39 non-null object
# dtypes: object(7)
# memory usage: 30.6+ KB

# %%
animals.head()
# Out:
#       Animal  Young Female  Male                    Collective noun  \
# 0          A    NaN    NaN   NaN                                NaN
# 1   Aardvark    cub    sow  boar                                NaN
# 2  Albatross  chick    NaN   NaN                           flock[6]
# 3        NaN    NaN    NaN   NaN                         rookery[7]
# 4        NaN    NaN    NaN   NaN  gam (when searching for mates)[8]
#
#   Collateral adjective Culinary noun for meat
# 0                  NaN                    NaN
# 1       orycteropodian                    NaN
# 2                    ?                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN

# %%
animals.tail()
# Out:
#     Animal Young Female      Male Collective noun Collateral adjective  \
# 554      Z   NaN    NaN       NaN             NaN                  NaN
# 555  Zebra  colt   mare  stallion     herd[9][88]              zebrine
# 556    NaN  foal    NaN       NaN      cohort[88]         hippotigrine
# 557    NaN   NaN    NaN       NaN     dazzle [89]                  NaN
# 558    NaN   NaN    NaN       NaN     zeal[9][88]                  NaN
#
#     Culinary noun for meat
# 554                    NaN
# 555                    NaN
# 556                    NaN
# 557                    NaN
# 558                    NaN

# %%
animals.shape
# Out:
# (559, 7)

# %%
animals.describe()
# Out:
#        Animal  Young Female Male Collective noun Collateral adjective  \
# count     255    301    227  235             447                  256
# unique    255     95     51   54             328                  191
# top      Lion  chick      ?    ?            herd                    ?
# freq        1     34     55   58              37                   31
#
#        Culinary noun for meat
# count                      39
# unique                     27
# top                   poultry
# freq                        7

# %%
animals.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
animals.mode()
# Out:
#                                Animal  Young Female Male Collective noun  \
# 0    (for American buffalo, seeBison)  chick      ?    ?            herd
# 1                                   A    NaN    NaN  NaN             NaN
# 2                            Aardvark    NaN    NaN  NaN             NaN
# 3                           Albatross    NaN    NaN  NaN             NaN
# 4                           Alligator    NaN    NaN  NaN             NaN
# 5                          Alpaca[10]    NaN    NaN  NaN             NaN
# 6                       Also see Aves    NaN    NaN  NaN             NaN
# 7                       Also see Boar    NaN    NaN  NaN             NaN
# 8                       Also see Duck    NaN    NaN  NaN             NaN
# 9                    Also see Mallard    NaN    NaN  NaN             NaN
# 10                       Also see Pig    NaN    NaN  NaN             NaN
# 11                       Also see Ram    NaN    NaN  NaN             NaN
# ...

# %%
plt.scatter(x=animals.Young,y=animals.Female,s=1,alpha=.3,c='red')
plt.xlabel('Young')
plt.ylabel('Female')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-18aa452981f6> in <module>()
#       1
# ----> 2 plt.scatter(x=animals.Young,y=animals.Female,s=1,alpha=.3,c='red')
#       3 plt.xlabel('Young')
#       4 plt.ylabel('Female')
#       5 plt.show()
#
# /srv/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# /srv/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...
